# %% [markdown]
# # ESGF Search demo
#
# The esgf-search package provides a simple interface to the [ESGF search API](https://earthsystemcog.org/projects/cog/esgf_search_restful_api).
#
# It also provides access to facet presets.
#
# First let's create a generic instance to explore the facets.

# %%
import esgf_search

esgf = esgf_search.ESGF()

# %% [markdown]
# ### Listing facets
#
# We'll print just the first two in the example but feel free to remove `[:2]` to view the entire list.

# %%
esgf.facets[:2]
# Out:
# ['project', 'product']

# %% [markdown]
# ### Listing values for a specific facet
#
# We'll again print the first two, remove `[:2]` to view the full list.

# %%
esgf.facet_values('project')[:2]
# Out:
# ['ACME', 'BioClim']

# %% [markdown]
# ### Create an instance to search the CMIP5 project
#
# Here we'll create an instance that will search the CMIP5 project for datasets and limit the results to 10 items per page.
#
# Alternatively this could be accomplished with `esgf = esgf_search.CMIP5(type='Dataset', limit=10)`. Presets for CMIP5 and CMIP6 exist.

# %%
esgf = esgf_search.ESGF(facet_query={'project': 'CMIP5'}, type='Dataset', limit=10)

# %% [markdown]
# Now that we've setup some default search criteria we can start more specific searches.
#
# For this example we'll look for datasets containing the variables `pr` in the `amip` experiment.
#
# The results will be scrubbed and returned in a [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html) from `Pandas`.
#
# **Remove `head(2)` to view the entire page of results.**

# %%
result = esgf.search(variable='pr', experiment='amip')
result.head(2)
# Out:
#                                                   id version  \
# 0  cmip5.output1.BCC.bcc-csm1-1.amip.mon.atmos.Am...       1
# 1  cmip5.output1.BCC.bcc-csm1-1.amip.mon.atmos.Am...       1
#
#                                         access  \
# 0  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
# 1  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
#
#                                     cf_standard_name cmor_table  \
# 0  [air_pressure_at_convective_cloud_base, air_pr...       Amon
# 1  [air_pressure_at_convective_cloud_base, air_pr...       Amon
#
#         data_node                               dataset_id_template_  \
# 0  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
# 1  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
#
#          datetime_start         datetime_stop  \
# 0  1979-01-16T12:00:00Z  2008-12-16T12:00:00Z
# 1  1979-01-16T12:00:00Z  2008-12-16T12:00:00Z
#
#                                        description  ...  \
# 0  bcc-csm1-1 model output prepared for CMIP5 AMIP  ...
# 1  bcc-csm1-1 model output prepared for CMIP5 AMIP  ...
#
#                                       variable_units  west_degrees  \
# 0  [Pa, Pa, 1e-9, 1, %, 1, kg m-2, %, 1, kg m-2, ...           0.0
# 1  [Pa, Pa, 1e-9, 1, %, 1, kg m-2, %, 1, kg m-2, ...           0.0
#
#              _version_ retracted                _timestamp score HTTPServer  \
# 0  1636912851766476800     False  2019-06-21T01:49:04.925Z   1.0        NaN
# 1  1636912858316931072     False  2019-06-21T01:49:11.172Z   1.0        NaN
#
#   GridFTP Globus  OPENDAP
# 0     NaN    NaN      NaN
# 1     NaN    NaN      NaN
#
# [2 rows x 54 columns]

# %% [markdown]
# We can further investigate and filter the results using the [DataFrame](https://pandas.pydata.org/pandas-docs/stable/reference/frame.html).
#
# Let's see the distribution for `time_frequency` and then filter by a specific value.

# %%
for x in result.groupby('time_frequency'):
    print(x[0], len(x))
# Out:
# 3hr 2
# day 2
# mon 2

# %%
filter_time_frequency = result[result.time_frequency=='3hr']
filter_time_frequency
# Out:
#                                                   id version  \
# 7  cmip5.output1.BCC.bcc-csm1-1.amip.3hr.atmos.3h...       1
# 8  cmip5.output1.BCC.bcc-csm1-1.amip.3hr.atmos.3h...       1
# 9  cmip5.output1.BCC.bcc-csm1-1.amip.3hr.atmos.3h...       1
#
#                                         access  \
# 7  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
# 8  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
# 9  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
#
#                                     cf_standard_name cmor_table  \
# 7  [cloud_area_fraction, surface_upward_latent_he...        3hr
# 8  [cloud_area_fraction, surface_upward_latent_he...        3hr
# 9  [cloud_area_fraction, surface_upward_latent_he...        3hr
#
#         data_node                               dataset_id_template_  \
# 7  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
# 8  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
# 9  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
#
#          datetime_start         datetime_stop  \
# 7  1979-01-01T00:00:00Z  2008-12-31T22:30:00Z
# 8  1979-01-01T00:00:00Z  2008-12-31T22:30:00Z
# 9  1979-01-01T00:00:00Z  2008-12-31T22:30:00Z
#
#                                        description  ...  \
# 7  bcc-csm1-1 model output prepared for CMIP5 AMIP  ...
# 8  bcc-csm1-1 model output prepared for CMIP5 AMIP  ...
# 9  bcc-csm1-1 model output prepared for CMIP5 AMIP  ...
#
#                                       variable_units  west_degrees  \
# 7  [%, W m-2, W m-2, kg m-2 s-1, kg m-2 s-1, kg m...           0.0
# 8  [%, W m-2, W m-2, kg m-2 s-1, kg m-2 s-1, kg m...           0.0
# 9  [%, W m-2, W m-2, kg m-2 s-1, kg m-2 s-1, kg m...           0.0
#
#              _version_ retracted                _timestamp score HTTPServer  \
# 7  1636912758700113920     False  2019-06-21T01:47:36.170Z   1.0        NaN
# 8  1636912762329235456     False  2019-06-21T01:47:39.631Z   1.0        NaN
# 9  1636912765217013760     False  2019-06-21T01:47:42.384Z   1.0        NaN
#
#   GridFTP Globus  OPENDAP
# 7     NaN    NaN      NaN
# 8     NaN    NaN      NaN
# 9     NaN    NaN      NaN
#
# [3 rows x 54 columns]

# %% [markdown]
# Since we limited the results to 10 items per page, we can navigate between these pages.
#
# Here we'll view the first two entries on the next page.
#
# **Remove `head(2)` to view the entire page of results.**

# %%
esgf.next().head(2)
# Out:
#                                                   id   version  \
# 0  cmip5.output1.IPSL.IPSL-CM5A-LR.amip.mon.atmos...  20110427
# 1  cmip5.output1.IPSL.IPSL-CM5A-LR.amip.mon.atmos...  20110427
#
#                                         access  \
# 0  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
# 1  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
#
#                                     cf_standard_name cmor_table  \
# 0  [air_pressure_at_convective_cloud_base, air_pr...       Amon
# 1  [air_pressure_at_convective_cloud_base, air_pr...       Amon
#
#         data_node                               dataset_id_template_  \
# 0  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
# 1  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
#
#          datetime_start         datetime_stop  \
# 0  1979-01-16T12:00:00Z  2009-12-16T12:00:00Z
# 1                   NaN                   NaN
#
#                                          description  ...  \
# 0  IPSL-CM5A-LR model output prepared for CMIP5 AMIP  ...
# 1  IPSL-CM5A-LR model output prepared for CMIP5 AMIP  ...
#
#                                       variable_units  west_degrees  \
# 0  [Pa, Pa, %, 1, kg m-2, %, 1, kg m-2, kg m-2 s-...           0.0
# 1  [Pa, Pa, %, 1, kg m-2, %, 1, kg m-2, kg m-2 s-...           NaN
#
#              _version_ retracted                _timestamp score HTTPServer  \
# 0  1636888982825467904     False  2019-06-20T19:29:41.728Z   1.0        NaN
# 1  1636888988517138432     False  2019-06-20T19:29:47.157Z   1.0        NaN
#
#   GridFTP Globus  OPENDAP
# 0     NaN    NaN      NaN
# 1     NaN    NaN      NaN
#
# [2 rows x 54 columns]

# %%
esgf.previous().head(2)
# Out:
#                                                   id   version  \
# 0  cmip5.output1.MIROC.MIROC5.amip.mon.atmos.Amon...  20120710
# 1  cmip5.output1.MIROC.MIROC5.amip.mon.atmos.Amon...  20120710
#
#                                         access  \
# 0  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
# 1  [HTTPServer, GridFTP, OPENDAP, Globus, LAS]
#
#                                     cf_standard_name cmor_table  \
# 0  [air_pressure_at_convective_cloud_base, air_pr...       Amon
# 1  [air_pressure_at_convective_cloud_base, air_pr...       Amon
#
#         data_node                               dataset_id_template_  \
# 0  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
# 1  aims3.llnl.gov  cmip5.output1.%(valid_institute)s.%(model)s.%(...
#
#          datetime_start         datetime_stop  \
# 0  1979-01-16T12:00:00Z  2008-12-16T12:00:00Z
# 1  1979-01-16T12:00:00Z  2008-12-16T12:00:00Z
#
#                                    description  ...  \
# 0  MIROC5 model output prepared for CMIP5 AMIP  ...
# 1  MIROC5 model output prepared for CMIP5 AMIP  ...
#
#                                       variable_units  west_degrees  \
# 0  [Pa, Pa, 1e-12, 1e-12, 1e-12, 1e-9, %, 1, kg m...           0.0
# 1  [Pa, Pa, 1e-12, 1e-12, 1e-12, 1e-9, %, 1, kg m...           0.0
#
#              _version_ retracted                _timestamp score HTTPServer  \
# 0  1636878732152012800     False  2019-06-20T16:46:45.924Z   1.0        NaN
# 1  1636878722531328000     False  2019-06-20T16:46:36.749Z   1.0        NaN
#
#   GridFTP Globus  OPENDAP
# 0     NaN    NaN      NaN
# 1     NaN    NaN      NaN
#
# [2 rows x 54 columns]
